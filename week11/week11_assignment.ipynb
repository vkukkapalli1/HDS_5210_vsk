# %% [markdown]
# <a href="https://colab.research.google.com/github/vkukkapalli1/HDS_5210_vsk/blob/main/week11/week11_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 11 Assignment
#
#
# Please do the programming exercise and verify that your code works using the tests, then think about your final project and fill out the questions in the second part.
#
# ---
# ---

# %% [markdown]
# ### 47.1: Filtering and summarizing data
#
# For this work, you'll find a data file in `/data/complications_all.csv`.
#
# Read in the data file and create a variable called `mo_hospitals` that contains a data frame from the `complications_all.csv` file, filtered down to only contain those hospitals from the state of Missouri (MO).
#
# Then aggregate that data by hospital into a variable named `mo_summary`.  There are some key fields that we want to summarize:
# * We want to know the earliest date that each hospital was participating in any program
# * We want to know the latest date that each hospital stopped participating in any program
# * We want to know the total number of patients in the denominators of these programs
#
# Some things to note:
# * You will need to convert the `Start Date` and `End Date` to actual datetime fields
# * You will need to clean up and convert the `Denominator` field to just be numeric - the rule that you should use it to simply remove any records where the `Denominator` is `'Not Available'`
#
#
# The final result of this step should be a new data frame called `mo_summary` that contains one row for each hospital and contains the min start date, max end date, and total denominator.  Use the names `start_date`, `end_date`, and `number` for those columns in `mo_summary`.
#
#
# You do not need to create your code in the form of a function, just make sure your variable names match what I've described above so the tests work.

# %%
import pandas as pd
# This is just to show you the name to use for the variable you need to create for this step to pass.
all_hospitals = pd.read_csv('/content/complications_all.csv')

# %%
# Do you work here and in as many cells as you need to create a variable called `mo_summary` that matches the requirements
mo_hospitals = all_hospitals[all_hospitals['State'] == 'MO']

mo_hospitals['Start Date'] = pd.to_datetime(mo_hospitals['Start Date'], format='%m/%d/%Y')
mo_hospitals['End Date'] = pd.to_datetime(mo_hospitals['End Date'], format='%m/%d/%Y')

mo_hospitals = mo_hospitals[mo_hospitals['Denominator'] != 'Not Available']
mo_hospitals['Denominator'] = pd.to_numeric(mo_hospitals['Denominator'])

mo_summary = mo_hospitals.groupby('Facility Name').agg(
    start_date=('Start Date', 'min'),
    end_date=('End Date', 'max'),
    number=('Denominator', 'sum')
).reset_index()

mo_summary.set_index('Facility Name', inplace=True)
# Out:
# <ipython-input-17-7b92d9f52826>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mo_hospitals['Start Date'] = pd.to_datetime(mo_hospitals['Start Date'], format='%m/%d/%Y')
# <ipython-input-17-7b92d9f52826>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mo_hospitals['End Date'] = pd.to_datetime(mo_hospitals['End Date'], format='%m/%d/%Y')

# %%
assert(mo_summary['number'].sum() == 1766908)
assert(mo_summary['start_date'].min() == pd.Timestamp(2015,4,1))
assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
assert(mo_summary.shape == (108,3))
assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
assert(mo_summary.loc['BOONE HOSPITAL CENTER'].number == 63099)

# %%
mo_summary.head()
# Out:
#                                    start_date   end_date  number
# Facility Name
# BARNES JEWISH HOSPITAL             2015-04-01 2018-06-30  131313
# BARNES-JEWISH ST PETERS HOSPITAL   2015-04-01 2018-06-30   15668
# BARNES-JEWISH WEST COUNTY HOSPITAL 2015-04-01 2018-06-30    9622
# BATES COUNTY MEMORIAL HOSPITAL     2015-07-01 2018-06-30    3117
# BELTON REGIONAL MEDICAL CENTER     2015-04-01 2018-06-30    9270

# %%
mo_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, BARNES JEWISH HOSPITAL to WRIGHT MEMORIAL HOSPITAL
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   start_date  108 non-null    datetime64[ns]
#  1   end_date    108 non-null    datetime64[ns]
#  2   number      108 non-null    int64
# dtypes: datetime64[ns](2), int64(1)
# memory usage: 7.4+ KB

# %%
mo_hospitals['Facility Name'].nunique()
# Out:
# 108

# %% [markdown]
# ---
#
# ### 47.2 Planning your final project
#
# You should be thinking about the things we've been learning and how you can apply them to your final project.  Use the rubric to help guid your thinking and then answer the questions below.  This is meant as a guide to help you think through what you will do.

# %% [markdown]
# #### A) Data Access
#
# Your project should include data from at least three distinct types of sources.  For example: AWS S3, Relational Databases, Internet, Web Services, local files.  List what data sources you're planning to use.

# %% [markdown]
# **Double-click to enter your answer**
#
# I'm planning to work on datasets related to scoccer,English Premier League with focusing mainly on data from Liverpool FC in the league. I've tried to search for the datasets for 2019-2020 season. I've found the datasets in Kaggle,Github and I'll also use local files which I've downloaded to cover the criteria where I have to use three distinct types of sources.
#
# EPL datasets in csv format from github- "https://github.com/tara-nguyen/english-premier-league-datasets-for-10-seasons/blob/main/epldat10seasons/epl1920matchday-goals-shots.csv"
#
# *pathway in the above repository-* " english-premier-league-datasets-for-10-seasons/epldat10seasons
# /epl1920matchday-goals-shots.csv"
#
#
#
#
# Epl datasets with matchday information from github in JSON format- "https://github.com/openfootball/football.json/blob/master/2019-20/en.1.json"
#
# *pathway for the json in above repository-*"football.json/2019-20
# /en.1.json"
#
#
#
#
# Epl dataset from kaggle in csv format that contains statistical data of teams, like expected goals, goals scored, etc. - "https://www.kaggle.com/datasets/idoyo92/epl-stats-20192020?select=epl2020.csv"

# %% [markdown]
# #### B. Data Formats
#
# Your project should include data that comes in different file formats.  For example: HL7, EDI, HTML, CSV, Excel, JSON, XML.  List what data formats you're planning to use.

# %% [markdown]
# **Double-click to enter your answer**
#
# The files I found so far are CSV and a JSON. So I plan on using JSON as well along with the csv files I found.
#
# EPL datasets in csv format from github- "https://github.com/tara-nguyen/english-premier-league-datasets-for-10-seasons/blob/main/epldat10seasons/epl1920matchday-goals-shots.csv"
#
# pathway in the above repository- " english-premier-league-datasets-for-10-seasons/epldat10seasons /epl1920matchday-goals-shots.csv"
#
# Epl datasets from github in JSON format- "https://github.com/openfootball/football.json/blob/master/2019-20/en.1.json"
#
# pathway for the json in above repository-"football.json/2019-20 /en.1.json"
#
# Epl dataset from kaggle in csv format - "https://www.kaggle.com/datasets/idoyo92/epl-stats-20192020?select=epl2020.csv"

# %%
# the above github links are accurate but when I'm opening then it says page not found.
# But if I try opening the repository and follow the same pathway its working.
# During my Final project i dont intend to use the above links but use:
1- "https://raw.githubusercontent.com/tara-nguyen/english-premier-league-datasets-for-10-seasons/refs/heads/main/epldat10seasons/epl1920matchday-goals-shots.csv"
2- "https://raw.githubusercontent.com/openfootball/football.json/refs/heads/master/2019-20/en.1.json"
# the dataset from kaggle, i intend to download and use as local file by uploading it into colab.
# I also found few other datasets which i intend to use if I need more data other than the existing datasets.

# %%
import pandas as pd
# for example
df1 = pd.read_csv("https://raw.githubusercontent.com/tara-nguyen/english-premier-league-datasets-for-10-seasons/refs/heads/main/epldat10seasons/epl1920matchday-goals-shots.csv")

# %%
df1.head()
# Out:
#           Club  M1GoalsScored  M2GoalsScored  M3GoalsScored  M4GoalsScored  \
# 0      Arsenal              1              2              1              2
# 1  Aston Villa              1              1              2              0
# 2  Bournemouth              1              2              1              1
# 3     Brighton              3              1              0              0
# 4      Burnley              3              1              1              0
#
#    M5GoalsScored  M6GoalsScored  M7GoalsScored  M8GoalsScored  M9GoalsScored  \
# 0              2              3              1              1              0
# 1              0              2              2              5              2
# 2              3              3              2              0              0
# 3              1              0              0              3              1
# 4              1              2              2              1              1
#
# ...

# %% [markdown]
# #### C. Objective
#
# What purpose would your project serve in a real work setting?  Take a couple of paragraphs to write down why this is an interesting product.

# %% [markdown]
# **Double-click to enter your answer**
#
#
#
# ***1) The main reason for my analysis is to find the shortcomings of teams, by comparing factors like the shots on target per game, goals scored, expected goals per game, etc. and then check the player stats with the same and how a team can improve by finding players that can overcome their shorcomings or the areas they need to improve from a data point-of-view.***
#
#  ***2) Yes, The analysis I plan to perform with the data I have allows me to create visualizations, which would make my analysis much more easier to interpret.***
#
#  ***3) I dont think the analysis I wish to perform is done by others on internet. Also I am performing this analysis from my own intrests and understanding of the concepts covered in the course so far.***
#
#  Basically, in recent years the sports teams are becoming more data driven and especially in Soccer. So by analyzing and visualizing the data, it can provide key insights for team management, coaches and sports analysts to find patterns and trends in past years which can help teams in strategy planning and player development and recruitment. The teams are now focusing on data to even go out to market to hire the coaches and players based on data the analysis of their playstyles and if it would suit their teams, if they can improve the current shortcomings of their team.
#
# By this project I believe, It can be useful for sports teams to improve the team performance and also improve the player performance by analysing their strengths and weaknessess in different areas..

# %% [markdown]
# ---
#
#
#
# ## Submit your work via GitHub as normal
